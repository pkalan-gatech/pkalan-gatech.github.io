# %% [markdown]
# # Algorithms

# %%
# !pip install matplotlib
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

data = np.random.randn(2, 100)
fig, ax = plt.subplots()
ax.scatter(*data, c=data[1], s=100*np.abs(data[0]));
# Out:
# Requirement already satisfied: matplotlib in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.cache/pypoetry/virtualenvs/pkalan-gatech-github-io-zGEN3eKU-py3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
